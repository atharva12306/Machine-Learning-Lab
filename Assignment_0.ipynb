# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [3, 6, 9, 12, 15]  # Y = 3X

plt.plot(x, y, marker='o', color='green', label='Y = 3X')
plt.title('Simple Line Graph')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.show()
